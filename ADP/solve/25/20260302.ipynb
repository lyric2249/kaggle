# %%
pd.DataFrame([[20,10],[15,30]], columns=['등산', '수영'], index=['남자', '여자'])
# Out:
#     등산  수영
# 남자  20  10
# 여자  15  30

# %%
import pandas as pd
df5= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/adp/25/problem5.csv',encoding='cp949')
df5.head(2)

df5_solve=df5

# %%
# df5_solve.groupby('공장명')['출하 소요시간'].median()
# df5_solve.groupby('공장명')['출하 소요시간'].count()

import scipy.stats as stats

stats.kruskal(
    df5_solve[df5_solve['공장명']=='X']['출하 소요시간']
    , df5_solve[df5_solve['공장명']=='Y']['출하 소요시간']
    , df5_solve[df5_solve['공장명']=='Z']['출하 소요시간']
)
# Out:
# KruskalResult(statistic=0.7217886080379153, pvalue=0.6970526702392181)

# %%
df6 = pd.DataFrame([[10,20,15],[15,14,19],[12,11,30],[13,25,20],[16,30,24]], columns = ['1개년','2개년','3개년'], index=['1안','2안','3안','4안','5안'])

# %%
pd.DataFrame()

# %%
df6_solve = df6

df6_solve
# Out:
#     1개년  2개년  3개년
# 1안   10   20   15
# 2안   15   14   19
# 3안   12   11   30
# 4안   13   25   20
# 5안   16   30   24

# %%
# from scipy.optimize import linprog

dir(scipy.optimize)
# Out:
# ['BFGS',
#  'Bounds',
#  'HessianUpdateStrategy',
#  'LbfgsInvHessProduct',
#  'LinearConstraint',
#  'NonlinearConstraint',
#  'OptimizeResult',
#  'OptimizeWarning',
#  'RootResults',
#  'SR1',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__nnls',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_basinhopping',
#  '_bglu_dense',
#  '_cobyla',
#  '_constraints',
#  '_differentiable_functions',
#  '_differentialevolution',
#  '_dual_annealing',
#  '_group_columns',
#  '_hessian_update_strategy',
#  '_highs',
#  '_lbfgsb',
#  '_linprog',
#  '_linprog_doc',
#  '_linprog_highs',
#  '_linprog_ip',
#  '_linprog_rs',
#  '_linprog_simplex',
#  '_linprog_util',
#  '_lsap',
#  '_lsap_module',
#  '_lsq',
#  '_minimize',
#  '_minpack',
#  '_nnls',
#  '_numdiff',
#  '_qap',
#  '_remove_redundancy',
#  '_root',
#  '_root_scalar',
#  '_shgo',
#  '_shgo_lib',
#  '_slsqp',
#  '_spectral',
#  '_trlib',
#  '_trustregion',
# ...
